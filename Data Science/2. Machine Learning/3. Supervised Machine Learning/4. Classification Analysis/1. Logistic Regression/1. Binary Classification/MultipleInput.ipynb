# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv("Datasets/Placement.csv")
dataset.head(3)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1

# %%
dataset.head(10)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0
# 5  7.30                  23.0       1
# 6  6.69                  11.0       0
# 7  7.12                  39.0       1
# 8  6.45                  38.0       0
# 9  7.75                  94.0       1

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="placement_exam_marks",data=dataset,hue="placed")
plt.legend(loc=1)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["placed"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 54.0

# %%
lr.predict([[7.19,26.0]])
# Out:
# d:\Programming\Python\Python\Interpreter\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
lr.coef_
# Out:
# array([[ 0.04126812, -0.00362242]])

# %%
lr.intercept_
# Out:
# array([-0.19019291])

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# d:\Programming\Python\Python\Interpreter\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

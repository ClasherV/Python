# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("Datasets/Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data=dataset.iloc[:,:-1]
output_data=dataset["medv"]

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.25)

# %%
x_train
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 185         186   0.06047   0.0   2.46     0  0.488  6.153   68.8  3.2797
# 263         264   0.82526  20.0   3.97     0  0.647  7.327   94.5  2.0788
# 249         250   0.19073  22.0   5.86     0  0.431  6.718   17.5  7.8265
# 79           80   0.08387   0.0  12.83     0  0.437  5.874   36.6  4.5026
# 213         214   0.14052   0.0  10.59     0  0.489  6.375   32.3  3.9454
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 419         420  11.81230   0.0  18.10     0  0.718  6.824   76.5  1.7940
# 379         380  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861
# 296         297   0.05372   0.0  13.92     0  0.437  6.549   51.0  5.9604
# 423         424   7.05042   0.0  18.10     0  0.614  6.103   85.1  2.0218
# 468         469  15.57570   0.0  18.10     0  0.580  5.926   71.0  2.9084
#
#      rad  tax  ptratio   black  lstat
# 185    3  193     17.8  387.11  13.15
# 263    5  264     13.0  393.42  11.25
# 249    7  330     19.1  393.74   6.56
# 79     5  398     18.7  396.06   9.10
# 213    4  277     18.6  385.81   9.38
# ..   ...  ...      ...     ...    ...
# 419   24  666     20.2   48.45  22.74
# 379   24  666     20.2  393.74  21.78
# 296    4  289     16.0  392.85   7.39
# 423   24  666     20.2    2.52  23.29
# 468   24  666     20.2  368.74  18.13
#
# [379 rows x 14 columns]

# %%
y_train
# Out:
# 185    29.6
# 263    31.0
# 249    26.2
# 79     20.3
# 213    28.1
#        ...
# 419     8.4
# 379    10.2
# 296    27.1
# 423    13.4
# 468    19.1
# Name: medv, Length: 379, dtype: float64

# %%
x_test
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 394         395  13.35980   0.0  18.10     0  0.693  5.887   94.7  1.7821
# 3             4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622
# 4             5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622
# 67           68   0.05789  12.5   6.07     0  0.409  5.878   21.4  6.4980
# 46           47   0.18836   0.0   6.91     0  0.448  5.786   33.3  5.1004
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 31           32   1.35472   0.0   8.14     0  0.538  6.072  100.0  4.1750
# 292         293   0.03615  80.0   4.95     0  0.411  6.630   23.4  5.1167
# 244         245   0.20608  22.0   5.86     0  0.431  5.593   76.5  7.9549
# 12           13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509
# 134         135   0.97617   0.0  21.89     0  0.624  5.757   98.4  2.3460
#
#      rad  tax  ptratio   black  lstat
# 394   24  666     20.2  396.90  16.35
# 3      3  222     18.7  394.63   2.94
# 4      3  222     18.7  396.90   5.33
# 67     4  345     18.9  396.21   8.10
# 46     3  233     17.9  396.90  14.15
# ..   ...  ...      ...     ...    ...
# 31     4  307     21.0  376.73  13.04
# 292    4  245     19.2  396.90   4.70
# 244    7  330     19.1  372.49  12.50
# 12     5  311     15.2  390.50  15.71
# 134    4  437     21.2  262.76  17.31
#
# [127 rows x 14 columns]

# %%
y_test
# Out:
# 394    12.7
# 3      33.4
# 4      36.2
# 67     22.0
# 46     20.0
#        ...
# 31     14.5
# 292    27.9
# 244    17.6
# 12     21.7
# 134    15.6
# Name: medv, Length: 127, dtype: float64

# %%
x_train.shape, y_train.shape
# Out:
# ((379, 14), (379,))

# %%
x_test.shape, y_test.shape
# Out:
# ((127, 14), (127,))
